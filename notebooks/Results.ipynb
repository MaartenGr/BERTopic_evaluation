# %% [markdown]
# # Evaluation Results

# %%
import evaluation
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Maarten\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Import results

# %%
results = evaluation.Results("../results/", combine_models=True); results.get_keys()
# Out:
# {'basic': ['20NewsGroup', 'BBC_news', 'trump', 'all'],
#  'dtm': ['trump_dtm', 'un_dtm', 'all']}

# %% [markdown]
# ## Exploration

# %%
results.get_data("BBC_news", aggregated=True)
# Out:
#                       npmi  diversity
# Model
# BERTopic          0.166772   0.794467
# BERTopic_Doc2Vec  0.168182   0.818800
# BERTopic_USE      0.158281   0.764167
# BERTopic_mini     0.169690   0.802011
# CTM_CUSTOM        0.094376   0.819022
# LDA               0.014025   0.577422
# NMF               0.012022   0.548967
# Top2Vec           0.171424   0.792022
# Top2Vec_mpnet    -0.027262   0.539644

# %%
results.get_data("trump", aggregated=True)
# Out:
#                       npmi  diversity
# Model
# BERTopic          0.065716   0.663122
# BERTopic_Doc2Vec -0.088243   0.535878
# BERTopic_USE      0.051320   0.684456
# BERTopic_mini     0.060012   0.659856
# CTM_CUSTOM        0.008559   0.855144
# LDA              -0.011037   0.502122
# NMF               0.008569   0.379400
# Top2Vec          -0.168862   0.658478
# Top2Vec_mpnet    -0.212655   0.698189

# %%
results.get_data("20NewsGroup", aggregated=True)
# Out:
#                       npmi  diversity
# Model
# BERTopic          0.165794   0.851311
# BERTopic_Doc2Vec  0.173051   0.870567
# BERTopic_USE      0.149256   0.858100
# BERTopic_mini     0.159116   0.832967
# CTM_CUSTOM        0.095925   0.885933
# LDA               0.057877   0.748867
# NMF               0.088868   0.662989
# Top2Vec           0.191573   0.822711
# Top2Vec_mpnet     0.067706   0.717922

# %%
results.get_data("un_dtm", dtm=True, aggregated=True)
# Out:
#                                npmi  diversity
# Model
# bertopic_all_tuning        0.248518   0.774751
# bertopic_evolution_tuning  0.226112   0.769255
# bertopic_global_tuning     0.253401   0.771707
# bertopic_no_tuning         0.231048   0.779235
# lda_seq                    0.173141   0.820296

# %%
results.get_data("trump_dtm", dtm=True, aggregated=True)
# Out:
#                                npmi  diversity
# Model
# bertopic_all_tuning        0.089871   0.870035
# bertopic_evolution_tuning  0.078712   0.863015
# bertopic_global_tuning     0.089433   0.867125
# bertopic_no_tuning         0.079131   0.861648
# lda_seq                    0.008619   0.714533

# %% [markdown]
# ## Results

# %%
models = ['Top2Vec_mpnet', 'LDA', 'NMF', 'CTM_CUSTOM', 'Top2Vec', 'BERTopic']
results.visualize_table(models=models)
# Out:
# <style type="text/css">
# #T_f796d_ th {
#   text-align: center;
# }
# #T_f796d_ td.col1 {
#   border-left: 2px solid #000066;
# }
# #T_f796d_ td.col3 {
#   border-left: 2px solid #000066;
# }
# #T_f796d_ td.col5 {
#   border-left: 2px solid #000066;
# }
# #T_f796d_row0_col0, #T_f796d_row0_col1, #T_f796d_row0_col2, #T_f796d_row0_col3, #T_f796d_row0_col4, #T_f796d_row0_col5, #T_f796d_row1_col0, #T_f796d_row1_col1, #T_f796d_row1_col2, #T_f796d_row1_col3, #T_f796d_row1_col4, #T_f796d_row1_col6, #T_f796d_row2_col0, #T_f796d_row2_col1, #T_f796d_row2_col2, #T_f796d_row2_col3, #T_f796d_row2_col4, #T_f796d_row2_col6, #T_f796d_row3_col0, #T_f796d_row4_col0, #T_f796d_row5_col0, #T_f796d_row5_col5, #T_f796d_row5_col6 {
#   width: 10em;
#   text-align: center;
# }
# #T_f796d_row0_col6, #T_f796d_row1_col5, #T_f796d_row3_col5, #T_f796d_row4_col1, #T_f796d_row4_col2, #T_f796d_row4_col3, #T_f796d_row4_col4 {
#   background-color: #76FF03;
#   width: 10em;
#   text-align: center;
# }
# #T_f796d_row2_col5, #T_f796d_row3_col1, #T_f796d_row3_col3, #T_f796d_row4_col6, #T_f796d_row5_col2, #T_f796d_row5_col4 {
#   background-color: #e1ffc7;
#   width: 10em;
#   text-align: center;
# }
# #T_f796d_row3_col2, #T_f796d_row3_col4, #T_f796d_row3_col6, #T_f796d_row4_col5, #T_f796d_row5_col1, #T_f796d_row5_col3 {
#   background-color: #64db00;
#   width: 10em;
#   text-align: center;
# }
# </style>
# <table id="T_f796d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" ></th>
#       <th class="col_heading level0 col1" colspan="2">20NewsGroup</th>
#       <th class="col_heading level0 col3" colspan="2">BBC_news</th>
#       <th class="col_heading level0 col5" colspan="2">trump</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >Model</th>
#       <th class="col_heading level1 col1" >npmi</th>
#       <th class="col_heading level1 col2" >diversity</th>
#       <th class="col_heading level1 col3" >npmi</th>
#       <th class="col_heading level1 col4" >diversity</th>
#       <th class="col_heading level1 col5" >npmi</th>
#       <th class="col_heading level1 col6" >diversity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f796d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f796d_row0_col0" class="data row0 col0" >Top2Vec_mpnet</td>
#       <td id="T_f796d_row0_col1" class="data row0 col1" >0.068</td>
#       <td id="T_f796d_row0_col2" class="data row0 col2" >0.718</td>
#       <td id="T_f796d_row0_col3" class="data row0 col3" >-0.027</td>
#       <td id="T_f796d_row0_col4" class="data row0 col4" >0.540</td>
#       <td id="T_f796d_row0_col5" class="data row0 col5" >-0.213</td>
#       <td id="T_f796d_row0_col6" class="data row0 col6" >0.698</td>
#     </tr>
#     <tr>
#       <th id="T_f796d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f796d_row1_col0" class="data row1 col0" >NMF</td>
#       <td id="T_f796d_row1_col1" class="data row1 col1" >0.089</td>
#       <td id="T_f796d_row1_col2" class="data row1 col2" >0.663</td>
#       <td id="T_f796d_row1_col3" class="data row1 col3" >0.012</td>
#       <td id="T_f796d_row1_col4" class="data row1 col4" >0.549</td>
#       <td id="T_f796d_row1_col5" class="data row1 col5" >0.009</td>
#       <td id="T_f796d_row1_col6" class="data row1 col6" >0.379</td>
#     </tr>
#     <tr>
#       <th id="T_f796d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f796d_row2_col0" class="data row2 col0" >LDA</td>
#       <td id="T_f796d_row2_col1" class="data row2 col1" >0.058</td>
#       <td id="T_f796d_row2_col2" class="data row2 col2" >0.749</td>
#       <td id="T_f796d_row2_col3" class="data row2 col3" >0.014</td>
#       <td id="T_f796d_row2_col4" class="data row2 col4" >0.577</td>
#       <td id="T_f796d_row2_col5" class="data row2 col5" >-0.011</td>
#       <td id="T_f796d_row2_col6" class="data row2 col6" >0.502</td>
#     </tr>
#     <tr>
#       <th id="T_f796d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f796d_row3_col0" class="data row3 col0" >CTM_CUSTOM</td>
#       <td id="T_f796d_row3_col1" class="data row3 col1" >0.096</td>
#       <td id="T_f796d_row3_col2" class="data row3 col2" >0.886</td>
#       <td id="T_f796d_row3_col3" class="data row3 col3" >0.094</td>
#       <td id="T_f796d_row3_col4" class="data row3 col4" >0.819</td>
#       <td id="T_f796d_row3_col5" class="data row3 col5" >0.009</td>
#       <td id="T_f796d_row3_col6" class="data row3 col6" >0.855</td>
#     </tr>
#     <tr>
#       <th id="T_f796d_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_f796d_row4_col0" class="data row4 col0" >BERTopic</td>
#       <td id="T_f796d_row4_col1" class="data row4 col1" >0.166</td>
#       <td id="T_f796d_row4_col2" class="data row4 col2" >0.851</td>
#       <td id="T_f796d_row4_col3" class="data row4 col3" >0.167</td>
#       <td id="T_f796d_row4_col4" class="data row4 col4" >0.794</td>
#       <td id="T_f796d_row4_col5" class="data row4 col5" >0.066</td>
#       <td id="T_f796d_row4_col6" class="data row4 col6" >0.663</td>
#     </tr>
#     <tr>
#       <th id="T_f796d_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_f796d_row5_col0" class="data row5 col0" >Top2Vec</td>
#       <td id="T_f796d_row5_col1" class="data row5 col1" >0.192</td>
#       <td id="T_f796d_row5_col2" class="data row5 col2" >0.823</td>
#       <td id="T_f796d_row5_col3" class="data row5 col3" >0.171</td>
#       <td id="T_f796d_row5_col4" class="data row5 col4" >0.792</td>
#       <td id="T_f796d_row5_col5" class="data row5 col5" >-0.169</td>
#       <td id="T_f796d_row5_col6" class="data row5 col6" >0.658</td>
#     </tr>
#   </tbody>
# </table>

# %%
results.visualize_table()
# Out:
# <style type="text/css">
# #T_acc93_ th {
#   text-align: center;
# }
# #T_acc93_ td.col1 {
#   border-left: 2px solid #000066;
# }
# #T_acc93_ td.col3 {
#   border-left: 2px solid #000066;
# }
# #T_acc93_ td.col5 {
#   border-left: 2px solid #000066;
# }
# #T_acc93_row0_col0, #T_acc93_row0_col1, #T_acc93_row0_col2, #T_acc93_row0_col3, #T_acc93_row0_col4, #T_acc93_row0_col5, #T_acc93_row1_col0, #T_acc93_row1_col1, #T_acc93_row1_col2, #T_acc93_row1_col3, #T_acc93_row1_col4, #T_acc93_row1_col5, #T_acc93_row1_col6, #T_acc93_row2_col0, #T_acc93_row2_col1, #T_acc93_row2_col2, #T_acc93_row2_col3, #T_acc93_row2_col4, #T_acc93_row2_col5, #T_acc93_row2_col6, #T_acc93_row3_col0, #T_acc93_row3_col1, #T_acc93_row3_col3, #T_acc93_row3_col5, #T_acc93_row4_col0, #T_acc93_row4_col1, #T_acc93_row4_col3, #T_acc93_row4_col4, #T_acc93_row5_col0, #T_acc93_row5_col2, #T_acc93_row5_col3, #T_acc93_row5_col6, #T_acc93_row6_col0, #T_acc93_row6_col5, #T_acc93_row6_col6, #T_acc93_row7_col0, #T_acc93_row7_col1, #T_acc93_row7_col2, #T_acc93_row7_col6, #T_acc93_row8_col0, #T_acc93_row8_col2, #T_acc93_row8_col4, #T_acc93_row8_col5, #T_acc93_row8_col6 {
#   width: 10em;
#   text-align: center;
# }
# #T_acc93_row0_col6, #T_acc93_row6_col1, #T_acc93_row6_col2, #T_acc93_row7_col3, #T_acc93_row7_col4, #T_acc93_row7_col5 {
#   background-color: #76FF03;
#   width: 10em;
#   text-align: center;
# }
# #T_acc93_row3_col2, #T_acc93_row3_col4, #T_acc93_row3_col6, #T_acc93_row5_col5, #T_acc93_row6_col4, #T_acc93_row8_col1, #T_acc93_row8_col3 {
#   background-color: #64db00;
#   width: 10em;
#   text-align: center;
# }
# #T_acc93_row4_col2, #T_acc93_row4_col5, #T_acc93_row4_col6, #T_acc93_row5_col1, #T_acc93_row5_col4, #T_acc93_row6_col3 {
#   background-color: #e1ffc7;
#   width: 10em;
#   text-align: center;
# }
# </style>
# <table id="T_acc93_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" ></th>
#       <th class="col_heading level0 col1" colspan="2">20NewsGroup</th>
#       <th class="col_heading level0 col3" colspan="2">BBC_news</th>
#       <th class="col_heading level0 col5" colspan="2">trump</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >Model</th>
#       <th class="col_heading level1 col1" >npmi</th>
#       <th class="col_heading level1 col2" >diversity</th>
#       <th class="col_heading level1 col3" >npmi</th>
#       <th class="col_heading level1 col4" >diversity</th>
#       <th class="col_heading level1 col5" >npmi</th>
#       <th class="col_heading level1 col6" >diversity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acc93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_acc93_row0_col0" class="data row0 col0" >Top2Vec_mpnet</td>
#       <td id="T_acc93_row0_col1" class="data row0 col1" >0.068</td>
#       <td id="T_acc93_row0_col2" class="data row0 col2" >0.718</td>
#       <td id="T_acc93_row0_col3" class="data row0 col3" >-0.027</td>
#       <td id="T_acc93_row0_col4" class="data row0 col4" >0.540</td>
#       <td id="T_acc93_row0_col5" class="data row0 col5" >-0.213</td>
#       <td id="T_acc93_row0_col6" class="data row0 col6" >0.698</td>
#     </tr>
#     <tr>
#       <th id="T_acc93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_acc93_row1_col0" class="data row1 col0" >NMF</td>
#       <td id="T_acc93_row1_col1" class="data row1 col1" >0.089</td>
#       <td id="T_acc93_row1_col2" class="data row1 col2" >0.663</td>
#       <td id="T_acc93_row1_col3" class="data row1 col3" >0.012</td>
#       <td id="T_acc93_row1_col4" class="data row1 col4" >0.549</td>
#       <td id="T_acc93_row1_col5" class="data row1 col5" >0.009</td>
#       <td id="T_acc93_row1_col6" class="data row1 col6" >0.379</td>
#     </tr>
#     <tr>
#       <th id="T_acc93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_acc93_row2_col0" class="data row2 col0" >LDA</td>
#       <td id="T_acc93_row2_col1" class="data row2 col1" >0.058</td>
#       <td id="T_acc93_row2_col2" class="data row2 col2" >0.749</td>
#       <td id="T_acc93_row2_col3" class="data row2 col3" >0.014</td>
#       <td id="T_acc93_row2_col4" class="data row2 col4" >0.577</td>
#       <td id="T_acc93_row2_col5" class="data row2 col5" >-0.011</td>
#       <td id="T_acc93_row2_col6" class="data row2 col6" >0.502</td>
#     </tr>
#     <tr>
#       <th id="T_acc93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_acc93_row3_col0" class="data row3 col0" >CTM_CUSTOM</td>
#       <td id="T_acc93_row3_col1" class="data row3 col1" >0.096</td>
#       <td id="T_acc93_row3_col2" class="data row3 col2" >0.886</td>
#       <td id="T_acc93_row3_col3" class="data row3 col3" >0.094</td>
#       <td id="T_acc93_row3_col4" class="data row3 col4" >0.819</td>
#       <td id="T_acc93_row3_col5" class="data row3 col5" >0.009</td>
#       <td id="T_acc93_row3_col6" class="data row3 col6" >0.855</td>
#     </tr>
#     <tr>
#       <th id="T_acc93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_acc93_row4_col0" class="data row4 col0" >BERTopic_USE</td>
#       <td id="T_acc93_row4_col1" class="data row4 col1" >0.149</td>
#       <td id="T_acc93_row4_col2" class="data row4 col2" >0.858</td>
#       <td id="T_acc93_row4_col3" class="data row4 col3" >0.158</td>
#       <td id="T_acc93_row4_col4" class="data row4 col4" >0.764</td>
#       <td id="T_acc93_row4_col5" class="data row4 col5" >0.051</td>
#       <td id="T_acc93_row4_col6" class="data row4 col6" >0.684</td>
#     </tr>
#     <tr>
#       <th id="T_acc93_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_acc93_row5_col0" class="data row5 col0" >BERTopic</td>
#       <td id="T_acc93_row5_col1" class="data row5 col1" >0.166</td>
#       <td id="T_acc93_row5_col2" class="data row5 col2" >0.851</td>
#       <td id="T_acc93_row5_col3" class="data row5 col3" >0.167</td>
#       <td id="T_acc93_row5_col4" class="data row5 col4" >0.794</td>
#       <td id="T_acc93_row5_col5" class="data row5 col5" >0.066</td>
#       <td id="T_acc93_row5_col6" class="data row5 col6" >0.663</td>
#     </tr>
#     <tr>
#       <th id="T_acc93_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_acc93_row6_col0" class="data row6 col0" >BERTopic_Doc2Vec</td>
#       <td id="T_acc93_row6_col1" class="data row6 col1" >0.173</td>
#       <td id="T_acc93_row6_col2" class="data row6 col2" >0.871</td>
#       <td id="T_acc93_row6_col3" class="data row6 col3" >0.168</td>
#       <td id="T_acc93_row6_col4" class="data row6 col4" >0.819</td>
#       <td id="T_acc93_row6_col5" class="data row6 col5" >-0.088</td>
#       <td id="T_acc93_row6_col6" class="data row6 col6" >0.536</td>
#     </tr>
#     <tr>
#       <th id="T_acc93_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_acc93_row7_col0" class="data row7 col0" >BERTopic_mini</td>
#       <td id="T_acc93_row7_col1" class="data row7 col1" >0.159</td>
#       <td id="T_acc93_row7_col2" class="data row7 col2" >0.833</td>
#       <td id="T_acc93_row7_col3" class="data row7 col3" >0.170</td>
#       <td id="T_acc93_row7_col4" class="data row7 col4" >0.802</td>
#       <td id="T_acc93_row7_col5" class="data row7 col5" >0.060</td>
#       <td id="T_acc93_row7_col6" class="data row7 col6" >0.660</td>
#     </tr>
#     <tr>
#       <th id="T_acc93_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_acc93_row8_col0" class="data row8 col0" >Top2Vec</td>
#       <td id="T_acc93_row8_col1" class="data row8 col1" >0.192</td>
#       <td id="T_acc93_row8_col2" class="data row8 col2" >0.823</td>
#       <td id="T_acc93_row8_col3" class="data row8 col3" >0.171</td>
#       <td id="T_acc93_row8_col4" class="data row8 col4" >0.792</td>
#       <td id="T_acc93_row8_col5" class="data row8 col5" >-0.169</td>
#       <td id="T_acc93_row8_col6" class="data row8 col6" >0.658</td>
#     </tr>
#   </tbody>
# </table>

# %%
results.visualize_table(dtm=True)
# Out:
# <style type="text/css">
# #T_c3989_ th {
#   text-align: center;
# }
# #T_c3989_ td.col3 {
#   border-left: 2px solid #000066;
# }
# #T_c3989_ td.col1 {
#   border-left: 2px solid #000066;
# }
# #T_c3989_row0_col0, #T_c3989_row0_col1, #T_c3989_row0_col2, #T_c3989_row0_col3, #T_c3989_row1_col0, #T_c3989_row1_col3, #T_c3989_row1_col4, #T_c3989_row2_col0, #T_c3989_row2_col2, #T_c3989_row3_col0, #T_c3989_row3_col4, #T_c3989_row4_col0 {
#   width: 10em;
#   text-align: center;
# }
# #T_c3989_row0_col4, #T_c3989_row3_col3, #T_c3989_row4_col1, #T_c3989_row4_col2 {
#   background-color: #64db00;
#   width: 10em;
#   text-align: center;
# }
# #T_c3989_row1_col1, #T_c3989_row1_col2, #T_c3989_row2_col1, #T_c3989_row2_col3, #T_c3989_row4_col4 {
#   background-color: #e1ffc7;
#   width: 10em;
#   text-align: center;
# }
# #T_c3989_row2_col4, #T_c3989_row3_col1, #T_c3989_row3_col2, #T_c3989_row4_col3 {
#   background-color: #76FF03;
#   width: 10em;
#   text-align: center;
# }
# </style>
# <table id="T_c3989_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" ></th>
#       <th class="col_heading level0 col1" colspan="2">trump_dtm</th>
#       <th class="col_heading level0 col3" colspan="2">un_dtm</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >Model</th>
#       <th class="col_heading level1 col1" >npmi</th>
#       <th class="col_heading level1 col2" >diversity</th>
#       <th class="col_heading level1 col3" >npmi</th>
#       <th class="col_heading level1 col4" >diversity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3989_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3989_row0_col0" class="data row0 col0" >lda_seq</td>
#       <td id="T_c3989_row0_col1" class="data row0 col1" >0.009</td>
#       <td id="T_c3989_row0_col2" class="data row0 col2" >0.715</td>
#       <td id="T_c3989_row0_col3" class="data row0 col3" >0.173</td>
#       <td id="T_c3989_row0_col4" class="data row0 col4" >0.820</td>
#     </tr>
#     <tr>
#       <th id="T_c3989_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3989_row1_col0" class="data row1 col0" >bertopic_evolution_tuning</td>
#       <td id="T_c3989_row1_col1" class="data row1 col1" >0.079</td>
#       <td id="T_c3989_row1_col2" class="data row1 col2" >0.863</td>
#       <td id="T_c3989_row1_col3" class="data row1 col3" >0.226</td>
#       <td id="T_c3989_row1_col4" class="data row1 col4" >0.769</td>
#     </tr>
#     <tr>
#       <th id="T_c3989_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c3989_row2_col0" class="data row2 col0" >bertopic_no_tuning</td>
#       <td id="T_c3989_row2_col1" class="data row2 col1" >0.079</td>
#       <td id="T_c3989_row2_col2" class="data row2 col2" >0.862</td>
#       <td id="T_c3989_row2_col3" class="data row2 col3" >0.231</td>
#       <td id="T_c3989_row2_col4" class="data row2 col4" >0.779</td>
#     </tr>
#     <tr>
#       <th id="T_c3989_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c3989_row3_col0" class="data row3 col0" >bertopic_global_tuning</td>
#       <td id="T_c3989_row3_col1" class="data row3 col1" >0.089</td>
#       <td id="T_c3989_row3_col2" class="data row3 col2" >0.867</td>
#       <td id="T_c3989_row3_col3" class="data row3 col3" >0.253</td>
#       <td id="T_c3989_row3_col4" class="data row3 col4" >0.772</td>
#     </tr>
#     <tr>
#       <th id="T_c3989_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c3989_row4_col0" class="data row4 col0" >bertopic_all_tuning</td>
#       <td id="T_c3989_row4_col1" class="data row4 col1" >0.090</td>
#       <td id="T_c3989_row4_col2" class="data row4 col2" >0.870</td>
#       <td id="T_c3989_row4_col3" class="data row4 col3" >0.249</td>
#       <td id="T_c3989_row4_col4" class="data row4 col4" >0.775</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Visualize Results

# %%
for dataset in results.get_keys()["basic"]:
    if dataset != "all":
        fig = results.plot_results(dataset, title=dataset, x="nr_topics", y="npmi", xlabel="Number of Topics",
                                    ylabel="npmi", figsize=(9, 5), confidence_interval=True)

# %%
for dataset in results.get_keys()["basic"]:
    if dataset != "all":
        fig = results.plot_results(dataset, title=dataset, x="nr_topics", y="diversity", xlabel="Number of Topics",
                                    ylabel="diversity", figsize=(9, 5), confidence_interval=True)

# %% [markdown]
# ## Computation

# %%
import matplotlib.pyplot as plt
labels = {'bertopic_use.csv': "BERTopic-USE",
          'bertopic_doc2vec.csv': "BERTopic-Doc2Vec",
          'bertopic_mini.csv': "BERTopic-MiniLM", 
          'bertopic_mpnet.csv': "BERTopic-MPNET",
          'ctm.csv': "CTM-MPNET", 
          'lda.csv': "LDA", 
          'nmf.csv': "NMF",
          'top2vec_doc2vec.csv': "Top2Vec-Doc2Vec",
          'top2vec_mpnet.csv': "Top2Vec-MPNET"}
fig = results.plot_computation(figsize=(5, 5), labels=labels, with_ctm=False)
# plt.savefig("../results/computation_without_ctm.png", dpi=300)

# %%
import matplotlib.pyplot as plt
labels = {'bertopic_use.csv': "BERTopic-USE",
          'bertopic_doc2vec.csv': "BERTopic-Doc2Vec",
          'bertopic_mini.csv': "BERTopic-MiniLM", 
          'bertopic_mpnet.csv': "BERTopic-MPNET",
          'ctm.csv': "CTM-MPNET", 
          'lda.csv': "LDA", 
          'nmf.csv': "NMF",
          'top2vec_doc2vec.csv': "Top2Vec-Doc2Vec",
          'top2vec_mpnet.csv': "Top2Vec-MPNET"}
fig = results.plot_computation(figsize=(5, 5), labels=labels, with_ctm=True)
# plt.savefig("../results/computation_with_ctm.png", dpi=300)
